# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'State Political Standing':['Strong Rep', 'Strong Dem', 'Weak Dem', 'Weak Rep'], 'val':[23, 19, 5, 3]})

ax = df.plot.bar(x='State Political Standing', y='val', color=['red', 'blue', 'blue', 'red'], rot=0, legend=None)

plt.title('State Party Control Count')
plt.xlabel('State Political Standing')
plt.ylabel('Number of States')
plt.tight_layout()
plt.show()
